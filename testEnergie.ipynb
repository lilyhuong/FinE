# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("data HDD europe.xlsx")

# %%
df
# Out:
#                     Unnamed: 0     Unit    2011 Unnamed: 3 Unnamed: 4  \
# 0                          NaN      NaN     Jan        Feb        Mar
# 1          Heating degree days  Degrees     423        369        301
# 2          Cooling degree days  Degrees    0.05          0          0
# 3  Net electricity consumption      GWh  255910     231708     238319
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 144  \
# 0        Apr        May        Jun        Jul        Aug  ...          Nov
# 1        138         88         39         36         24  ...          271
# 2       5.25      18.74      45.56      59.05       73.9  ...         0.74
# 3     202572     204460     199330     207367     202373  ...    200189.56
#
#   Unnamed: 145        2023 Unnamed: 147 Unnamed: 148 Unnamed: 149  \
# 0          Dec         Jan          Feb          Mar          Apr
# 1          397        n.a.         n.a.         n.a.         n.a.
# ...

# %%
df = df.drop(columns=['Unnamed: 1', 'Unnamed: 151', 'Unnamed: 152'])

# %%
df
# Out:
#                     Unnamed: 0 Unnamed: 1        Jan     Feb     Mar  \
# 0          Heating degree days    Degrees     423.00     369     301
# 1          Cooling degree days    Degrees       0.05       0       0
# 2  Net electricity consumption        GWh  255910.00  231708  238319
#
#          Apr        May        Jun        Jul       Aug  ...      Oct.11  \
# 0     138.00      88.00      39.00      36.00      24.0  ...     113.000
# 1       5.25      18.74      45.56      59.05      73.9  ...       9.500
# 2  202572.00  204460.00  199330.00  207367.00  202373.0  ...  191494.594
#
#       Nov.11      Dec.11      Jan.12      Feb.12  Mar.12  Apr.12  May.12  \
# 0     271.00     397.000        n.a.        n.a.    n.a.    n.a.    n.a.
# 1       0.74       0.020        n.a.        n.a.    n.a.    n.a.    n.a.
# 2  200189.56  216143.673  223578.626  205318.184    n.a.    n.a.    n.a.
#
#    Unnamed: 151                                       Unnamed: 152
# ...
